# %%
import pandas as pd
chemin = 'assets/category_youtube.json'
df = pd.read_json(chemin)
df.head()
# Out:
#                   Nature                                                Tag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#
#    Identifiant                    Chaine             title  assignable snippet
# 0            1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation         1.0    None
# 1            2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles         1.0    None
# 2           10  UCBR8-60-B28hp2BmDPdntcQ             Music         1.0    None
# 3           15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals         1.0    None
# 4           17  UCBR8-60-B28hp2BmDPdntcQ            Sports         1.0    None

# %%
df.rename(columns={'kind': 'Nature', 
                   'channelId': 'Chaine', 
                   'id': 'Identifiant', 
                   'etag': 'Tag'}, 
          inplace=True)
df.head()
# Out:
#                   Nature                                                Tag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#
#    Identifiant                    Chaine             title  assignable snippet
# 0            1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation         1.0     NaN
# 1            2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles         1.0     NaN
# 2           10  UCBR8-60-B28hp2BmDPdntcQ             Music         1.0     NaN
# 3           15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals         1.0     NaN
# 4           17  UCBR8-60-B28hp2BmDPdntcQ            Sports         1.0     NaN

# %%
df.to_json(chemin)
cheminCSV = 'assets/youtube.csv'
df.to_csv(cheminCSV, sep='|')

# %%
dfCSV = pd.read_csv(cheminCSV, sep='|')
dfCSV .head()
# Out:
#    Unnamed: 0                 Nature  \
# 0           0  youtube#videoCategory
# 1           1  youtube#videoCategory
# 2           2  youtube#videoCategory
# 3           3  youtube#videoCategory
# 4           4  youtube#videoCategory
#
#                                                  Tag  Identifiant  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...            1
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...            2
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...           10
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...           15
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...           17
#
#                      Chaine             title  assignable snippet
# 0  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation         1.0     NaN
# 1  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles         1.0     NaN
# 2  UCBR8-60-B28hp2BmDPdntcQ             Music         1.0     NaN
# 3  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals         1.0     NaN
# ...
