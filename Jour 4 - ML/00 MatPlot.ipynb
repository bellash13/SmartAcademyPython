# %%
import matplotlib.pyplot as plt
import math

# %%
X = [0, 45, 90, 180, 360]
Y = [math.sin(x) for x in X]
plt.plot(X, Y)
plt.title('Fortune par age')
plt.xlabel('Age')
plt.ylabel('Fortune')
# Out:
# Text(0, 0.5, 'Fortune')
